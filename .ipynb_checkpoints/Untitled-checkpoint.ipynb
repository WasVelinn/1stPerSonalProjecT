# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
orders = pd.read_csv('data/orders.csv')
order_products_prior = pd.read_csv('data/order_products__prior.csv')
products = pd.read_csv('data/products.csv')
aisles = pd.read_csv('data/aisles.csv')
departments = pd.read_csv('data/departments.csv')

# %%
orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# total_orders : 총 주문횟수
total_orders = orders.groupby('user_id')['order_number'].max()
total_orders
# Out:
# user_id
# 1         11
# 2         15
# 3         13
# 4          6
# 5          5
#           ..
# 206205     4
# 206206    68
# 206207    17
# 206208    50
# 206209    14
# Name: order_number, Length: 206209, dtype: int64

# %%
# days_since_last_order : 마지막 주문 이후 경과한 일수
orders.groupby('user_id')['order_number'].max()
# Out:
# user_id
# 1         11
# 2         15
# 3         13
# 4          6
# 5          5
#           ..
# 206205     4
# 206206    68
# 206207    17
# 206208    50
# 206209    14
# Name: order_number, Length: 206209, dtype: int64

# %%
def last_order_days(series):
# Out:
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
#             ...
# 3421078    206209
# 3421079    206209
# 3421080    206209
# 3421081    206209
# 3421082    206209
# Name: user_id, Length: 3421083, dtype: int64

# %%
merged_df = pd.merge(orders, total_orders, on='user_id', how='left')

# %%
days_since_last_order = merged_df[merged_df['order_number_x'] == merged_df['order_number_y']].iloc[:, -2]
days_since_last_order
# Out:
# 10         14.0
# 25         30.0
# 38         11.0
# 44         30.0
# 49          6.0
#            ...
# 3420933    10.0
# 3421001     0.0
# 3421018    14.0
# 3421068     4.0
# 3421082    30.0
# Name: days_since_prior_order, Length: 206209, dtype: float64

# %%
# order_cycle : 주문 주기성(주문 간격의 평균)
order_cycle = orders.groupby('user_id')['days_since_prior_order'].mean()
order_cycle
# Out:
# user_id
# 1         19.000000
# 2         16.285714
# 3         12.000000
# 4         17.000000
# 5         11.500000
#             ...
# 206205    16.666667
# 206206     3.716418
# 206207    14.312500
# 206208     7.367347
# 206209    18.461538
# Name: days_since_prior_order, Length: 206209, dtype: float64

# %%
# average_basket_size : 평균 장바구니 크기

# %%
orders[orders['order_id'] == 2]
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3355525         2   202279    prior             3          5
#
#          order_hour_of_day  days_since_prior_order
# 3355525                  9                     8.0

# %%
cart_max = order_products_prior.groupby('order_id')['add_to_cart_order'].max()
cart_max
# Out:
# order_id
# 2           9
# 3           8
# 4          13
# 5          26
# 6           3
#            ..
# 3421079     1
# 3421080     9
# 3421081     7
# 3421082     7
# 3421083    10
# Name: add_to_cart_order, Length: 3214874, dtype: int64

# %%
average_basket_size = pd.merge(orders, cart_max, on='order_id', how='left').groupby('user_id')['add_to_cart_order'].mean()
average_basket_size
# Out:
# user_id
# 1          5.900000
# 2         13.928571
# 3          7.333333
# 4          3.600000
# 5          9.250000
#             ...
# 206205    10.666667
# 206206     4.253731
# 206207    13.937500
# 206208    13.816327
# 206209     9.923077
# Name: add_to_cart_order, Length: 206209, dtype: float64

# %%
pd.merge(orders, cart_max, on='order_id', how='left')
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order  add_to_cart_order
# 0                        8                     NaN                5.0
# 1                        7                    15.0                6.0
# ...

# %%
# num_departments : 고객이 구매한 부서의 개수
order_products_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
products_drop = products.drop(['product_name', 'aisle_id'], axis=1)
products_drop
# Out:
#        product_id  department_id
# 0               1             19
# 1               2             13
# 2               3              7
# 3               4              1
# 4               5             13
# ...           ...            ...
# 49683       49684              5
# 49684       49685              1
# 49685       49686              3
# 49686       49687              8
# 49687       49688             11
#
# [49688 rows x 2 columns]

# %%
merged_products = pd.merge(order_products_prior, products_drop, on='product_id', how='left').groupby('order_id')['department_id'].nunique()
merged_products
# Out:
# order_id
# 2           3
# 3           4
# 4           5
# 5          11
# 6           2
#            ..
# 3421079     1
# 3421080     4
# 3421081     7
# 3421082     5
# 3421083     5
# Name: department_id, Length: 3214874, dtype: int64

# %%
pd.merge(order_products_prior, products_drop, on='product_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 pd.merge(order_products_prior, products_drop, on='product_id', how='left')
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:124, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
#     110     op = _MergeOperation(
#     111         left,
#     112         right,
#    (...)
#     122         validate=validate,
#     123     )
# --> 124     return op.get_result(copy=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:773, in _MergeOperation.get_result(self, copy)
#     770 if self.indicator:
# ...

# %%
average_basket_size
# Out:
# user_id
# 1          5.900000
# 2         13.928571
# 3          7.333333
# 4          3.600000
# 5          9.250000
#             ...
# 206205    10.666667
# 206206     4.253731
# 206207    13.937500
# 206208    13.816327
# 206209     9.923077
# Name: add_to_cart_order, Length: 206209, dtype: float64

# %%
num_departments = pd.merge(orders, merged_products, on='order_id', how='left').groupby('user_id')['department_id'].mean()
num_departments
# Out:
# user_id
# 1         3.700000
# 2         5.642857
# 3         4.083333
# 4         3.000000
# 5         4.000000
#             ...
# 206205    4.333333
# 206206    2.805970
# 206207    6.312500
# 206208    6.448980
# 206209    6.538462
# Name: department_id, Length: 206209, dtype: float64

# %%
pd.merge(orders, merged_products, on='order_id', how='left').loc[:20]
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
# num_products : 고객이 구매한 고유한 상품의 수

# %%
order_products_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
order_id_products_count = order_products_prior.groupby('order_id')['product_id'].count()

# %%
orders_product_merge = pd.merge(orders, order_id_products_count, on='order_id', how='left')

# %%
order_products_prior.iloc[:50]
# Out:
#     order_id  product_id  add_to_cart_order  reordered
# 0          2       33120                  1          1
# 1          2       28985                  2          1
# 2          2        9327                  3          0
# 3          2       45918                  4          1
# 4          2       30035                  5          0
# 5          2       17794                  6          1
# 6          2       40141                  7          1
# 7          2        1819                  8          1
# 8          2       43668                  9          0
# 9          3       33754                  1          1
# 10         3       24838                  2          1
# 11         3       17704                  3          1
# 12         3       21903                  4          1
# 13         3       17668                  5          1
# 14         3       46667                  6          1
# 15         3       17461                  7          1
# ...

# %%
num_products = orders_product_merge.groupby('user_id')['product_id'].sum()

# %%
orders_product_merge.iloc[:50]
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
# order_hour_of_day : 고객이 주문한 시간대 평균
order_hour_of_day = orders.groupby('user_id')['order_hour_of_day'].mean()

# %%
order_hour_of_day
# Out:
# user_id
# 1         10.090909
# 2         10.600000
# 3         16.307692
# 4         12.500000
# 5         15.000000
#             ...
# 206205    14.750000
# 206206    16.779412
# 206207    12.529412
# 206208    14.200000
# 206209    13.642857
# Name: order_hour_of_day, Length: 206209, dtype: float64

# %%
# order_dow : 고객이 주문한 요일 평균
order_dow = round(orders.groupby('user_id')['order_dow'].mean()).astype('int')
order_dow
# Out:
# user_id
# 1         3
# 2         2
# 3         1
# 4         4
# 5         1
#          ..
# 206205    3
# 206206    2
# 206207    3
# 206208    3
# 206209    3
# Name: order_dow, Length: 206209, dtype: int32

# %%
order_dow, order_hour_of_day, num_products
# Out:
# (user_id
#  1         3
#  2         2
#  3         1
#  4         4
#  5         1
#           ..
#  206205    3
#  206206    2
#  206207    3
#  206208    3
#  206209    3
#  Name: order_dow, Length: 206209, dtype: int32,
#  user_id
#  1         10.090909
#  2         10.600000
#  3         16.307692
#  4         12.500000
#  5         15.000000
#              ...
#  206205    14.750000
#  206206    16.779412
#  206207    12.529412
#  206208    14.200000
#  206209    13.642857
#  Name: order_hour_of_day, Length: 206209, dtype: float64,
#  user_id
#  1          59.0
#  2         195.0
#  3          88.0
#  4          18.0
#  5          37.0
#            ...
#  206205     32.0
#  206206    285.0
#  206207    223.0
#  206208    677.0
#  206209    129.0
#  Name: product_id, Length: 206209, dtype: float64)

# %%
num_departments, average_basket_size, order_cycle
# Out:
# (user_id
#  1         3.700000
#  2         5.642857
#  3         4.083333
#  4         3.000000
#  5         4.000000
#              ...
#  206205    4.333333
#  206206    2.805970
#  206207    6.312500
#  206208    6.448980
#  206209    6.538462
#  Name: department_id, Length: 206209, dtype: float64,
#  user_id
#  1          5.900000
#  2         13.928571
#  3          7.333333
#  4          3.600000
#  5          9.250000
#              ...
#  206205    10.666667
#  206206     4.253731
#  206207    13.937500
#  206208    13.816327
#  206209     9.923077
#  Name: add_to_cart_order, Length: 206209, dtype: float64,
#  user_id
#  1         19.000000
#  2         16.285714
#  3         12.000000
#  4         17.000000
#  5         11.500000
#              ...
#  206205    16.666667
#  206206     3.716418
#  206207    14.312500
#  206208     7.367347
#  206209    18.461538
#  Name: days_since_prior_order, Length: 206209, dtype: float64)

# %%
days_since_last_order, total_orders
# Out:
# (10         14.0
#  25         30.0
#  38         11.0
#  44         30.0
#  49          6.0
#             ...
#  3420933    10.0
#  3421001     0.0
#  3421018    14.0
#  3421068     4.0
#  3421082    30.0
#  Name: days_since_prior_order, Length: 206209, dtype: float64,
#  user_id
#  1         11
#  2         15
#  3         13
#  4          6
#  5          5
#            ..
#  206205     4
#  206206    68
#  206207    17
#  206208    50
#  206209    14
#  Name: order_number, Length: 206209, dtype: int64)

# %%
serieses = [total_orders, days_since_last_order, order_cycle, average_basket_size, num_departments, num_products, order_hour_of_day, order_dow]
serieses[]
# Out:
#         user_id  order_number
# 0             1            11
# 1             2            15
# 2             3            13
# 3             4             6
# 4             5             5
# ...         ...           ...
# 206204   206205             4
# 206205   206206            68
# 206206   206207            17
# 206207   206208            50
# 206208   206209            14
#
# [206209 rows x 2 columns]

# %%
frames = []
for i in range(len(serieses)):
    if i<=1 :
        frames.append(serieses[i])
    else :
        frames.append(serieses[i].to_frame())

# %%
frames[4]
# Out:
#          department_id
# user_id
# 1             3.700000
# 2             5.642857
# 3             4.083333
# 4             3.000000
# 5             4.000000
# ...                ...
# 206205        4.333333
# 206206        2.805970
# 206207        6.312500
# 206208        6.448980
# 206209        6.538462
#
# [206209 rows x 1 columns]

# %%
result = frames[0]
for i in range(1, len(frames)):
    result = pd.merge(result, frames[i], on='user_id', how='left')

# %%
result.columns = ['user_id', 'order_number', 'days_since_last_order', 'order_cycle', 'average_basket_size', 'num_departments',
                  'num_products', 'order_hour_of_day', 'order_dow']
result
# Out:
#         user_id  order_number  days_since_last_order  order_cycle  \
# 0             1            11                   14.0    19.000000
# 1             2            15                   30.0    16.285714
# 2             3            13                   11.0    12.000000
# 3             4             6                   30.0    17.000000
# 4             5             5                    6.0    11.500000
# ...         ...           ...                    ...          ...
# 206204   206205             4                   10.0    16.666667
# 206205   206206            68                    0.0     3.716418
# 206206   206207            17                   14.0    14.312500
# 206207   206208            50                    4.0     7.367347
# 206208   206209            14                   30.0    18.461538
#
#         average_basket_size  num_departments  num_products  order_hour_of_day  \
# 0                  5.900000         3.700000          59.0          10.090909
# ...

# %%
frames[1]
# Out:
#          days_since_prior_order
# 10                         14.0
# 25                         30.0
# 38                         11.0
# 44                         30.0
# 49                          6.0
# ...                         ...
# 3420933                    10.0
# 3421001                     0.0
# 3421018                    14.0
# 3421068                     4.0
# 3421082                    30.0
#
# [206209 rows x 1 columns]

# %%
frames[7]
# Out:
#          order_dow
# user_id
# 1                3
# 2                2
# 3                1
# 4                4
# 5                1
# ...            ...
# 206205           3
# 206206           2
# 206207           3
# 206208           3
# 206209           3
#
# [206209 rows x 1 columns]

# %%
frames[1]
# Out:
#          days_since_prior_order
# 10                         14.0
# 25                         30.0
# 38                         11.0
# 44                         30.0
# 49                          6.0
# ...                         ...
# 3420933                    10.0
# 3421001                     0.0
# 3421018                    14.0
# 3421068                     4.0
# 3421082                    30.0
#
# [206209 rows x 1 columns]

# %%
total_orders.to_frame().reset_index()
# Out:
#         user_id  order_number
# 0             1            11
# 1             2            15
# 2             3            13
# 3             4             6
# 4             5             5
# ...         ...           ...
# 206204   206205             4
# 206205   206206            68
# 206206   206207            17
# 206207   206208            50
# 206208   206209            14
#
# [206209 rows x 2 columns]

# %%
orders['user_id'] == orders.iloc
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
def last_days(series):
    series['user_id']
# Out:
#         user_id  order_number
# 0             1            11
# 1             2            15
# 2             3            13
# 3             4             6
# 4             5             5
# ...         ...           ...
# 206204   206205             4
# 206205   206206            68
# 206206   206207            17
# 206207   206208            50
# 206208   206209            14
#
# [206209 rows x 2 columns]

# %%
total_orders = total_orders.to_frame().reset_index()

# %%
total_orders
# Out:
#         user_id  order_number
# 0             1            11
# 1             2            15
# 2             3            13
# 3             4             6
# 4             5             5
# ...         ...           ...
# 206204   206205             4
# 206205   206206            68
# 206206   206207            17
# 206207   206208            50
# 206208   206209            14
#
# [206209 rows x 2 columns]

# %%
orders['order_number'] == orders.groupby('user_id')['order_number'].max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 orders['order_number'] == orders.groupby('user_id')['order_number'].max()
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:6237, in Series._cmp_method(self, other, op)
#    6234 res_name = ops.get_op_result_name(self, other)
#    6236 if isinstance(other, Series) and not self._indexed_same(other):
# ...

# %%
max_order = orders.groupby('user_id')['order_number'].idxmax()

# %%
days_since_last_order = orders.loc[max_order].drop(['order_id', 'eval_set', 'order_number', 'order_dow', 'order_hour_of_day'], axis=1).reset_index(drop=True)

# %%
days_since_last_order
# Out:
#         user_id  days_since_prior_order
# 0             1                    14.0
# 1             2                    30.0
# 2             3                    11.0
# 3             4                    30.0
# 4             5                     6.0
# ...         ...                     ...
# 206204   206205                    10.0
# 206205   206206                     0.0
# 206206   206207                    14.0
# 206207   206208                     4.0
# 206208   206209                    30.0
#
# [206209 rows x 2 columns]

# %%
result['days_since_last_order'] > 25
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 206204    False
# 206205    False
# 206206    False
# 206207    False
# 206208     True
# Name: days_since_last_order, Length: 206209, dtype: bool
